# %% [markdown]
# <a href="https://colab.research.google.com/github/yashrajmodani/Data-Analaysis/blob/main/Day6_variance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
#separate data based on gender
df_male = df[df['Gender'] == 'Male']
df_female = df[df['Gender'] == 'Female']

# %%
#Calculate correlation
corr_overall = df[['Height', 'Weight']].corr()
corr_male = df_male[['Height', 'Weight']].corr()
corr_female = df_female[['Height', 'Weight']].corr()

print("Overall correlation between height and weight")
print(corr_overall)
print("Male correlation between height and weight")
print(corr_male)
print("Women correlation between height and weight")
print(corr_female)
# Out:
# Overall correlation between height and weight
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000
# Male correlation between height and weight
#           Height    Weight
# Height  1.000000  0.862979
# Weight  0.862979  1.000000
# Women correlation between height and weight
#           Height    Weight
# Height  1.000000  0.849609
# Weight  0.849609  1.000000

# %%
#Calculate covariance
cov_overall = df[['Height', 'Weight']].cov()
cov_male = df_male[['Height', 'Weight']].cov()
cov_female = df_female[['Height', 'Weight']].cov()

print("Overall covariance between height and weight")
print(cov_overall)
print("Male covariance between height and weight")
print(cov_male)
print("Women covariance between height and weight")
print(cov_female)
# Out:
# Overall covariance between height and weight
#             Height       Weight
# Height   14.803473   114.242656
# Weight  114.242656  1030.951855
# Male covariance between height and weight
#            Height      Weight
# Height   8.198843   48.879649
# Weight  48.879649  391.294074
# Women covariance between height and weight
#            Height      Weight
# Height   7.269947   43.576404
# Weight  43.576404  361.854281

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

#overall data plot
axes[0].scatter(df['Height'], df['Weight'],color = 'red', alpha = 0.5)
axes[0].set_title(f'Overall correlation:{corr_overall.loc["Height", "Weight"]:.2f}')
axes[0].set_xlabel('Height')
axes[0].set_ylabel('Weight')
axes[0].grid(True)

#Male data plot
axes[1].scatter(df_male['Height'], df_male['Weight'],color = 'skyblue', alpha = 0.5)
axes[1].set_title(f'Male correlation:{corr_male.loc["Height", "Weight"]:.2f}')
axes[1].set_xlabel('Height')
axes[1].set_ylabel('Weight')
axes[1].grid(True)

#Female data plot
axes[2].scatter(df_female['Height'], df_female['Weight'],color = 'black', alpha = 0.5)
axes[2].set_title(f'Female correlation:{corr_female.loc["Height", "Weight"]:.2f}')
axes[2].set_xlabel('Height')
axes[2].set_ylabel('Weight')
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %%
df2 = pd.read_csv('/SP500 oil gold bitcoin.csv')
df2.head()
# Out:
#          Date  BITCOIN  Brent Oil  Crude Oil WTI    Gold   S&P500
# 0  2010-07-18      0.1      75.37          76.01  1188.0  1064.88
# 1  2010-07-19      0.1      75.62          76.54  1181.7  1071.25
# 2  2010-07-20      0.1      76.22          77.44  1191.5  1083.48
# 3  2010-07-21      0.1      75.37          76.56  1191.6  1069.59
# 4  2010-07-22      0.1      77.82          79.30  1195.5  1093.67

# %%
#separate data based on oil
corr_gold = df2[['BITCOIN', 'Gold']].corr()
corr_SP500 = df2[['BITCOIN', 'S&P500']].corr()

print("Overall correlation between bitcoin and oil")
print(corr_gold)
print("Overall correlation between bitcoin and SP500")
print(corr_SP500)
# Out:
# Overall correlation between bitcoin and oil
#           BITCOIN      Gold
# BITCOIN  1.000000  0.594622
# Gold     0.594622  1.000000
# Overall correlation between bitcoin and SP500
#           BITCOIN    S&P500
# BITCOIN  1.000000  0.862225
# S&P500   0.862225  1.000000

# %%
#overall plot between bitcoin and gold
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].scatter(df2['BITCOIN'], df2['Gold'],color = 'red', alpha = 0.5)
axes[0].set_title(f'Overall correlation:{corr_gold.loc["BITCOIN", "Gold"]:.2f}')
axes[0].set_xlabel('Bitcoin')
axes[0].set_ylabel('Gold')
axes[0].grid(True)

plt.text(text_x,text_y,f"Correlation: {corr_gold.loc['BITCOIN', 'Gold']:.2f}", ha = 'center', va ='center',fontsize = 12)

#overall plot between bitcoin and s&p500
axes[1].scatter(df2['BITCOIN'], df2['S&P500'],color = 'black', alpha = 0.5)
axes[1].set_title(f'Overall correlation:{corr_SP500.loc["BITCOIN", "S&P500"]:.2f}')
axes[1].set_xlabel('Bitcoin')
axes[1].set_ylabel('S&P500')
axes[1].grid(True)

plt.text(text_x,text_y,f"Correlation: {corr_SP500.loc['BITCOIN', 'S&P500']:.2f}", ha = 'center', va ='center',fontsize = 12)

xmin, xmax = plt.xlim()
ymin, ymax = plt.ylim()

#Set the text position at 70% of the x- axis and 30% of th y-axis range
text_x = xmin + (xmax - xmin) * 0.7
text_y = ymin + (ymax - ymin) * 0.3



plt.tight_layout()
plt.show()
