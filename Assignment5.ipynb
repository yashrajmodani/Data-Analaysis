# %% [markdown]
# <a href="https://colab.research.google.com/github/yashrajmodani/Data-Analaysis/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **# 1. Write a Python programming to display a bar chart of the popularity of
# programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.bar(programming,popularity,color = 'b')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.xlim(-0.4)
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.show()

# %% [markdown]
# **# 2. Write a Python programming to display a horizontal bar chart of the
# popularity of programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.barh(programming,popularity,color = 'g')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.tight_layout()
plt.ylim(-0.4)
plt.show()

# %% [markdown]
# **# 3. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Use uniform color.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.bar(programming,popularity,color = 'b')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)

plt.ylim(0.4)
plt.xlim(-0.4)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **# 4. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Use different color for each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.bar(programming,popularity,color=plt.cm.Set1(np.arange(len(programming))))
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.xlim(-0.4)
plt.show()

# %% [markdown]
# **# 5. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Attach a text label above each bar displaying its
# popularity (float value).
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.bar(programming,popularity,color = 'b')
bar_container = plt.bar(programming, popularity)
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.bar_label(bar_container,fmt='{:,.5f}')
plt.minorticks_on()
plt.xlim(-0.4)
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.show()

# %% [markdown]
# **6. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Make blue border to each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.bar(programming,popularity,color = 'c',edgecolor = 'b')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.xlim(-0.4)
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.show()

# %% [markdown]
# **7. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Specify the position of each bar plot.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]
x_pos = [0,1,5,8,10,11]

plt.bar(x_pos,popularity,color = 'b')
plt.xticks(x_pos, programming)
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.xlim(-0.4)
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.show()

# %% [markdown]
# **8. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Select the width of each bar and their positions.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]
x_pos = [0,1,5,8,10,11]
width = [0.8,0.2,2,1.5,0.3,0.5]
plt.bar(x_pos,popularity,color = 'b',width = width)
plt.xticks(x_pos, programming)
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.xlim(-0.4)
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.show()

# %% [markdown]
# **9. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Increase bottom margin.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7**

# %%
programming = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2,17.6,8.8,8,7.7,6.7]

plt.bar(programming,popularity,color = 'b',)
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.xlim(-0.4)
plt.subplots_adjust(bottom = 1,top=1.3)
plt.xticks(rotation = 90)
plt.grid(True,alpha = 0.2,ls = '-',which = 'major',color = 'r',lw = 1)
plt.grid(True,alpha = 0.1,ls = '-',which = 'minor',color = 'b',lw = 1)
plt.show()

# %% [markdown]
# **10. Write a Python program to create bar plot of scores by group and gender.
# Use multiple X values on the same chart for men and women.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)**

# %%
X =['G1','G2','G3','G4','G5']
men = [22, 30, 35, 35, 26]
women = [25, 32, 30, 50, 29]

X_axis = np.arange(len(X))
plt.bar(X_axis -0.2,men,0.4,label = 'Men')
plt.bar(X_axis +0.2,women,0.4,label = 'Women')
plt.xticks(X_axis,X)

plt.xlabel("Person")
plt.ylabel("Scores")
plt.title("Scores by Person")
plt.legend()
plt.show()

# %% [markdown]
# **11. Write a Python program to create bar plot from a DataFrame.
# Sample Data Frame:
# a b c d e
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2**

# %%
data = {'index': ['a','b','c','d','e'],
        '1':[4,8,5,7,6],
        '2': [2,3,4,2,6],
        '3': [4,7,4,7,8],
        '4': [2,6,4,8,6],
        '5': [2,4,3,3,2]}
df = pd.DataFrame(data)
df.set_index('index', inplace=True)

ax = df.plot(kind='bar', rot=0)

plt.legend(loc = 'upper right')
plt.xlabel('index')
plt.ylabel('values')
plt.show()

# %% [markdown]
# **12. Write a Python program to create bar plots with error bars on the same
# figure.
# Sample Date
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645**

# %%
mv = [0.2474,0.1235,0.1737,0.1824]
sv = [0.03314,0.02278,0.02836,0.02645]


plt.bar([0,1,2,3],mv,yerr= sv, align ='edge', width = 0.3,color = 'r')

plt.xlabel('Velocity')
plt.ylabel('SDV')
plt.legend('Men')
plt.show()

# %% [markdown]
# **13. Write a Python program to create bar plots with errorbars on the same
# figure. Attach a text label above each bar displaying men means (integer
# value).
# Sample Data
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645**

# %%
mv = [0.2474,0.1235,0.1737,0.1824]
sv = [0.03314,0.02278,0.02836,0.02645]



bar_container = plt.bar([0,1,2,3],mv,yerr= sv, align ='edge', width = 0.3,color = 'r')
plt.bar_label(bar_container,fmt='{:,.5f}')

plt.xlabel('Velocity')
plt.ylabel('SDV')
plt.legend('Men')
plt.show()

# %% [markdown]
# **14. Write a Python program to create a stacked bar plot with error bars.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)
# Men Standard deviation = (4, 3, 4, 1, 5)
# Women Standard deviation = (3, 5, 2, 3, 3)**

# %%
N = 5
menMeans = (22, 30, 35, 35, 26)
womenMeans = (25, 32, 30, 35, 29)
menStd = (4, 3, 4, 1, 5)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)
width = 0.35

p1 = plt.bar(ind, menMeans, width, yerr=menStd, color='red')
p2 = plt.bar(ind, womenMeans, width,bottom=menMeans, yerr=womenStd, color='green')

plt.ylabel('Scores')
plt.xlabel('Groups')
plt.title('Scores by group and gender')
plt.xticks(ind, ('Group1', 'Group2', 'Group3', 'Group4', 'Group5'))
plt.legend(('Men', 'Women'))

plt.show()

# %% [markdown]
# **15. Write a Python program to create a horizontal bar chart with differently
# ordered colors.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.
# Sample Data Set:
# languages = [['Language','Science','Math'],
# ['Science','Math','Language'],
# ['Math','Language','Science']]
# numbers = [{'Language':75, 'Science':88, 'Math':96},
# {'Language':71, 'Science':95, 'Math':92},
# {'Language':75, 'Science':90, 'Math':89}]**

# %%
lan = [['Language','Science','Math'],
            ['Science','Math','Language'],
            ['Math','Language','Science']]
num = [{'Language':75, 'Science':88, 'Math':96},
          {'Language':71, 'Science':95, 'Math':92},
          {'Language':75, 'Science':90, 'Math':89}]


students = ['Student1','Student2','Student3']

plt.barh(students[0],num[0][lan[0][0]])
plt.barh(students[0],num[0][lan[0][1]],left = num[0][lan[0][0]])
plt.barh(students[0],num[0][lan[0][0]],left = num[0][lan[0][0]] + num[0][lan[0][1]])

plt.barh(students[1],num[1][lan[1][0]])
plt.barh(students[1],num[1][lan[1][1]],left = num[1][lan[1][0]])
plt.barh(students[1],num[1][lan[1][0]],left = num[1][lan[1][0]] + num[1][lan[1][1]])

plt.barh(students[2],num[2][lan[2][0]])
plt.barh(students[2],num[2][lan[2][1]],left = num[2][lan[2][0]])
plt.barh(students[2],num[2][lan[2][0]],left = num[2][lan[2][0]] + num[2][lan[2][1]])
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red',alpha = 0.5)
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black',alpha = 0.2)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **16. Write a Python program to create stack bar plot and add label to each
# section.
# Sample data:
# people = ('G1','G2','G3','G4','G5','G6','G7','G8')
# segments = 4
#
#  multi-dimensional data
# data = [[ 3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039,
# 7.1123587, 12.77792868, 3.44773477],
# [ 11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195,
# 6.79685302, 7.24578743, 3.69371847],
# [ 3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182,
# 4.63832778, 11.16849999, 8.56883433],
# [ 4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185,
# 10.97567589, 3.98287652, 8.80552122]]**

# %%
people = ('G1','G2','G3','G4','G5','G6','G7','G8')
segments = 4

# multi-dimensional data
data = [[  3.40022085,   7.70632498,   6.4097905,   10.51648577,   7.5330039,
    7.1123587,   12.77792868,   3.44773477],
 [ 11.24811149,   5.03778215,   6.65808464,  12.32220677,   7.45964195,
    6.79685302,   7.24578743,   3.69371847],
 [  3.94253354,   4.74763549,  11.73529246,   4.6465543,   12.9952182,
    4.63832778,  11.16849999,   8.56883433],
 [  4.24409799,  12.71746612,  11.3772169,    9.00514257,  10.47084185,
   10.97567589,   3.98287652,   8.80552122]]
percentages = (np.random.randint(5,20, (len(people), segments)))
y_pos = np.arange(len(people))

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)

colors ='rgwm'
patch_handles = []
# left alignment of data starts at zero
left = np.zeros(len(people))
for i, d in enumerate(data):
    patch_handles.append(ax.barh(y_pos, d,
      color=colors[i%len(colors)], align='center',
      left=left))
    left += d

# search all of the bar segments and annotate
for j in range(len(patch_handles)):
    for i, patch in enumerate(patch_handles[j].get_children()):
        bl = patch.get_xy()
        x = 0.5*patch.get_width() + bl[0]
        y = 0.5*patch.get_height() + bl[1]
        ax.text(x,y, "%d%%" % (percentages[i,j]), ha='center')

ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.set_xlabel('Scores')
plt.show()

# %% [markdown]
# **17. Write a Python program to add textures (black and white) to bars and
# wedges.
# Note: Use bottom to stack the womens bars on top of the mens bars.
# The code snippet gives the output shown in the following screenshot:**

# %%
fig = plt.figure()
patterns = [ "|" , "\\" , "/" , "+" , "-", ".", "*","x", "o", "O" ,'X']

ax = fig.add_subplot(111)
for i in range(len(patterns)):
    ax.bar(i, 3, color='white', edgecolor='black', hatch=patterns[i])

plt.show()
